# %% [markdown]
# # Movielens 영화 추천 실습

# %% [markdown]
# ## 데이터 준비와 전처리

# %%
import os
import pandas as pd
#rating_file_path = os.getenv('HOME')+'/aiffel/recommendata_iu/data/ml-1m/ratings.dat'

# %%
os.getcwd()
# Out:
# 'D:\\AI\\first-repository'

# %%
#win 버전 메타데이터 위치 변화
rating_file_path = 'D:\\AI\\first-repository/ratings.dat'

# %%
# win 버전 제목메타데이터 변화
movie_file_path = 'D:\\AI\\first-repository/movies.dat'

# %%
ratings_cols = ['user_id', 'movie_id', 'rating', 'timestamp']

# %%
ratings=pd.read_csv(rating_file_path, sep="::", names=ratings_cols, engine='python')

# %%
original_data_size = len(ratings)

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
# 3점 이상만 남김
ratings = ratings[ratings['rating']>=3]
filtered_data_size = len(ratings)

print(f'original_data_size:{original_data_size}, filtered_data_size:{filtered_data_size}')
print(f'Ratio of Remaining Data is {filtered_data_size / original_data_size:.2%}')
# Out:
# original_data_size:1000209, filtered_data_size:836478
# Ratio of Remaining Data is 83.63%

# %%
# rating column의 이름을 count로 변경
ratings.rename(columns={'rating':'count'}, inplace=True)

# %%
ratings.keys()
# Out:
# Index(['user_id', 'movie_id', 'count', 'timestamp'], dtype='object')

# %%
# # 영화제목을 보기위해 메타데이터를 읽어옴
# movie_file_path=os.getenv('HOME') + '/aiffel/recommendata_iu/data/ml-1m/movies.dat'
cols = ['movie_id', 'title', 'genre']

# %%
movies = pd.read_csv(movie_file_path, sep='::', names=cols, engine='python')
movies.head()
# Out:
#    movie_id                               title                         genre
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings.head()
# Out:
#    user_id  movie_id  count  timestamp
# 0        1      1193      5  978300760
# 1        1       661      3  978302109
# 2        1       914      3  978301968
# 3        1      3408      4  978300275
# 4        1      2355      5  978824291

# %% [markdown]
# * 유니크한 영화갯수

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
# movie_id    3883 non-null int64
# title       3883 non-null object
# genre       3883 non-null object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %%
movies.movie_id.nunique()
# Out:
# 3883

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 836478 entries, 0 to 1000208
# Data columns (total 3 columns):
# user_id     836478 non-null int64
# movie_id    836478 non-null int64
# count       836478 non-null int64
# dtypes: int64(3)
# memory usage: 65.5 MB

# %% [markdown]
# * 유니크한 사용자수

# %%
ratings.user_id.nunique()
# Out:
# 6039

# %% [markdown]
# * 가장 인기있는 영화 30개(인기순)

# %%
movie_count = ratings.groupby('movie_id')['count'].sum()
movie_count.sort_values(ascending=False).head(30)
# Out:
# movie_id
# 2858    14449
# 260     13178
# 1196    12648
# 2028    11348
# 1210    11303
# 1198    11179
# 593     11096
# 2571    10903
# 2762    10703
# 589     10513
# 608     10465
# 527     10317
# 110     10125
# 318     10085
# 1270    10081
# 858      9965
# 1197     9866
# 480      9601
# 1617     9515
# 2396     9503
# 1580     9057
# 296      9053
# 2997     8964
# 1265     8727
# 1097     8696
# 356      8679
# 1240     8571
# 1        8475
# 2716     8282
# 1214     8244
# Name: count, dtype: int64

# %% [markdown]
# * 내가 좋아하는 영화 5개

# %%
import re

# %%
movies['title'] = movies.title.str.lower()

# %%
my_movie = ['gladiator','die hard','mask','terminator 2', 'home alone']

# %%
aa =movies.title.tolist()

# %%
aa
# Out:
# ['toy story (1995)',
#  'jumanji (1995)',
#  'grumpier old men (1995)',
#  'waiting to exhale (1995)',
#  'father of the bride part ii (1995)',
#  'heat (1995)',
#  'sabrina (1995)',
#  'tom and huck (1995)',
#  'sudden death (1995)',
#  'goldeneye (1995)',
#  'american president, the (1995)',
#  'dracula: dead and loving it (1995)',
#  'balto (1995)',
#  'nixon (1995)',
#  'cutthroat island (1995)',
#  'casino (1995)',
#  'sense and sensibility (1995)',
#  'four rooms (1995)',
#  'ace ventura: when nature calls (1995)',
#  'money train (1995)',
#  'get shorty (1995)',
#  'copycat (1995)',
#  'assassins (1995)',
#  'powder (1995)',
#  'leaving las vegas (1995)',
#  'othello (1995)',
#  'now and then (1995)',
#  'persuasion (1995)',
#  'city of lost children, the (1995)',
#  'shanghai triad (yao a yao yao dao waipo qiao) (1995)',
#  'dangerous minds (1995)',
#  'twelve monkeys (1995)',
#  'wings of courage (1995)',
#  'babe (1995)',
#  'carrington (1995)',
# ...

# %%
len(aa)
# Out:
# 3883

# %%
word = re.compile('gladiator|die hard|mask|terminator 2|home alone')

# %%
for i,name in enumerate(aa):
    pattern = word.search(name)
    if pattern is not None:
        print(i)
        print(name)
        
    else:
        continue
# Out:
# 163
# die hard: with a vengeance (1995)
# 363
# mask, the (1994)
# 582
# home alone (1990)
# 585
# terminator 2: judgment day (1991)
# 1023
# die hard (1988)
# 1349
# die hard 2 (1990)
# 1659
# home alone 3 (1997)
# 1740
# man in the iron mask, the (1998)
# 1937
# mask of zorro, the (1998)
# 2540
# king of masks, the (bian lian) (1996)
# 2556
# black mask (hak hap) (1996)
# 2884
# home alone 2: lost in new york (1992)
# 3144
# batman: mask of the phantasm (1993)
# 3509
# gladiator (2000)

# %%
movies.head()
# Out:
#    movie_id                               title                         genre
# 0         1                    toy story (1995)   Animation|Children's|Comedy
# 1         2                      jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             grumpier old men (1995)                Comedy|Romance
# 3         4            waiting to exhale (1995)                  Comedy|Drama
# 4         5  father of the bride part ii (1995)                        Comedy

# %%
ratings.head()
# Out:
#    user_id  movie_id  count  timestamp
# 0        1      1193      5  978300760
# 1        1       661      3  978302109
# 2        1       914      3  978301968
# 3        1      3408      4  978300275
# 4        1      2355      5  978824291

# %%
# 163
# die hard: with a vengeance (1995)
# 363
# mask, the (1994)
# 585
# terminator 2: judgment day (1991)
# 3509
# gladiator (2000)
# 582
# home alone (1990)

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 836478 entries, 0 to 1000208
# Data columns (total 4 columns):
# user_id      836478 non-null int64
# movie_id     836478 non-null int64
# count        836478 non-null int64
# timestamp    836478 non-null int64
# dtypes: int64(4)
# memory usage: 31.9 MB

# %% [markdown]
# * 내 정보 입력

# %%
my_list = pd.DataFrame({'user_id':['jin']*5, 'movie_id':[163,363,585,3509,582], 'count':[5,5,5,5,4]})

# %%
my_list
# Out:
#   user_id  movie_id  count
# 0     jin       163      5
# 1     jin       363      5
# 2     jin       585      5
# 3     jin      3509      5
# 4     jin       582      4

# %% [markdown]
# * CSR MAtrix 만들기

# %%
ratings = ratings.loc[:,['user_id','movie_id','count']]

# %%
ratings_1 = ratings.append(my_list)
